# %% [markdown]
# 1. Import Preprocessed Data

# %%
import pandas as pd

X_train = pd.read_csv('https://raw.githubusercontent.com/NavneetsScripts/salary_prediction_ml/refs/heads/main/data/ds_salaries.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/NavneetsScripts/salary_prediction_ml/refs/heads/main/data/ds_salaries.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/NavneetsScripts/salary_prediction_ml/refs/heads/main/data/ds_salaries.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/NavneetsScripts/salary_prediction_ml/refs/heads/main/data/ds_salaries.csv')

y = X_train['salary_in_usd']
X = X_train.drop(['salary_in_usd', 'salary', 'salary_currency'], axis=1)
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (3755, 8)
# Shape of y: (3755,)

# %% [markdown]
# 2. Import Libraries

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %% [markdown]
# 3. Categorical feature identification

# %%
categorical_cols = [col for col in X.columns if X[col].dtype in ['object', 'category']]
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: ['experience_level', 'employment_type', 'job_title', 'employee_residence', 'company_location', 'company_size']

# %% [markdown]
# 4. One-hot encoding

# %%
X_train = X_train.drop(['salary', 'salary_currency', 'salary_in_usd'], axis=1)
X_test = X_test.drop(['salary', 'salary_currency', 'salary_in_usd'], axis=1)

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ],
    remainder='passthrough'
)

X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

print("Shape of processed X_train:", X_train_processed.shape)
print("Shape of processed X_test:", X_test_processed.shape)
# Out:
# Shape of processed X_train: (3755, 256)
# Shape of processed X_test: (3755, 256)

# %% [markdown]
#  5. Define Evaluation Function

# %%
def evaluate_model(y_true, y_pred):
    print("MAE:", mean_absolute_error(y_true, y_pred))
    print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print("R² Score:", r2_score(y_true, y_pred))

# %% [markdown]
# 6. Model training

# %%
print(y_train.head())
y_train = y_train['salary_in_usd']
print(y_train.head())
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %% [markdown]
#  Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train_processed, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model evaluation

# %%
y_pred_lr = lr.predict(X_test_processed)
print("Linear Regression Results:")
evaluate_model(y_test['salary_in_usd'], y_pred_lr)
# Out:
# Linear Regression Results:
# MAE: 34005.02704871582
# RMSE: 45425.244486330106
# R² Score: 0.4808862329603524

# %% [markdown]
# Random Forest

# %%
rf = RandomForestRegressor()
rf.fit(X_train_processed, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Model evaluation

# %%
y_pred_rf = rf.predict(X_test_processed)
print(" RandomForestRegressor Results:")
evaluate_model(y_test['salary_in_usd'], y_pred_rf)
# Out:
#  RandomForestRegressor Results:
# MAE: 30006.246042708677
# RMSE: 40949.488499177496
# R² Score: 0.5781432888894036

# %% [markdown]
# 7. Save Best Model

# %%
import joblib

joblib.dump(rf, 'final_model.pkl')
# Out:
# ['final_model.pkl']
